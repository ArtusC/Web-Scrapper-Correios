# %%
# Caso a biblioteca TABLATE não esteja instala, rodar o código abaixo
#!pip install -q tabulate

# %%
# Bibliotecas utilizadas
import pandas as pd
import requests, bs4, urllib.request, urllib.parse, re, requests_html, json
from tabulate import tabulate

# %%
# Função que retorna o conteúdo da URL
def make_soup(url):
    r = requests.get(url)
    soup = bs4.BeautifulSoup(r.text, 'lxml')
    return soup

# Função que retorna o FORM onde estará o botão com a requisição
def get_form(soup):
    form = soup.form
    return form

# Função que retorna a URL absoluta a partir da action do form da página inicial
def get_action(form, base_url):
    action = form['action']
    action_modified = action.split("/")[2]
    #action is reletive url, convert it to absolute url
    abs_action = urllib.parse.urljoin(base_url, action_modified)
    return abs_action

# Função que retorna os parâmetros para serem enviados no POST da página inicial
# O único que é required é o UF
def get_form_data(form, UF):
    data = {}   
    for inpInput, inpSelect in zip(form('input'), form('select')):
        data[inpSelect['name']] = UF
        if inpInput.value == None:
            data[inpInput['name']] = ' '
        else:
            data[inpInput['name']] = inpInput.value 
            data['Bairro'] = ''    
    return data

# Função que retorna os parâmetros para serem enviados no POST nas páginas de resultado (no botão SEGUINTE)
# Aqui, preciso do UF e da página inicial e final, contidas no form do resultado
def get_form_data_proxima(UF, pgIni, pgFim):
    dataProxima = {}     
    dataProxima['UF'] = UF
    dataProxima['Bairro'] = ''    
    dataProxima['pagini'] = pgIni
    dataProxima['pagfim'] = pgFim
    return dataProxima

# Função que retorna a URL absoluta a partir da action do form da página de resultado
def get_action_proxima(formProxima, base_url):
    action_modified_proxima = formProxima.split("/")[2]
    #action is reletive url, convert it to absolute url
    abs_action_proxima = urllib.parse.urljoin(base_url, action_modified_proxima)
    return abs_action_proxima

# %%
while True:
    try:
        if __name__ == '__main__':
                        
            url = 'http://www.buscacep.correios.com.br/sistemas/buscacep/buscaFaixaCep.cfm'
            
            # Digito a sigla do estado que quero fazer a raspagem de dados
            UF_escolha = str(input('Digite a sigla de algum estado: '))
            
            # Lista com as siglas corretas dos estados 
            listaEstados = ['AC','AL','AM','AP','BA','CE','DF','ES','GO','MA','MG','MS',\
                            'MT','PA','PB','PE','PI','PR','RJ','RN','RO','RR','RS','SC','SE','SP','TO']
            
            # Verifico a sigla digitada com a sigla contida na lista
            if UF_escolha.upper() not in listaEstados:
                print("Estado não existente, digite novamente.")
                UF_escolha = None
            else:
                UF_escolha = UF_escolha.upper()
            
            # DIV que receberá todas as tabelas no final
            divTables = bs4.BeautifulSoup('<div></div>')
            
            # Como não consigo pegar na página de resultado inicial o valor da pagIni e pagFim (para acessar as outras páginas),
            # esse LOOP (a partir do 1) vai percorrendo cada página com os parâmetros necessários pagIni e pagFim, 
            # que são separados por 49 linhas.
            # ex: pagIni=1 e pagFim=50 (segunda página dos resultados), pagIni=51 e pagFim=100 (terceira página dos resultados)
            for i in range(0,20):
                pagI = 1+(50*i)
                pagF = 50+(50*i)
                if i==0:
                    soup = make_soup(url)
                    form = get_form(soup)
                    action = get_action(form, url)
                    data = get_form_data(form, UF_escolha)
                    # Realizo o POST na página inicial que me traz os resultados (separados por páginas)
                    rResult = requests.post(action, data=data)
                    soupResult = bs4.BeautifulSoup(rResult.content, "html5lib")
                    # Tabela contendo o resultado
                    tableInit = soupResult.find_all("table", {"class":"tmptabela"})[1]
                    # Guardo o resultado na DIV
                    divTables.append(tableInit)              
                else:
                    form_proxima = soupResult.find('form')
                    form_action_proxima = form_proxima['action']
                    dataNew = get_form_data_proxima(UF_escolha, pagI, pagF)
                    action_proxima = get_action_proxima(form_action_proxima, url)
                    # Realizo o POST nas páginas de resultados para acessar a página seguinte
                    rResult_proxima = requests.post(action_proxima, data=dataNew)
                    soupResult = bs4.BeautifulSoup(rResult_proxima.content, "html5lib")
                    # Tabela contendo o resultado
                    tableInit = soupResult.find_all("table", {"class":"tmptabela"})[0]
                    # Guardo o resultado na DIV
                    divTables.append(tableInit)
               
    except TypeError:
        # Esse except indica que ele só tinha uma página de resultado
        print("\nRaspagem das faixas de CEP do estado "+ UF_escolha +" concluída.")
        break
    except IndexError:
        # Esse except indica que ele chegou na última página de resultado
        print("\nRaspagem das faixas de CEP do estado "+ UF_escolha +" concluída.")
        break    
    else:
        break
# Out:
# Digite a sigla de algum estado: ro
#
# Raspagem das faixas de CEP do estado RO concluída.

# %%
# Caso seja necessário mostrar todas as linas do resultado:
# pd.set_option('display.max_rows', None)

# Quantidade de linhas
lenTables = len(divTables.find_all('table'))

# Crio o DF
df = pd.concat([pd.concat(pd.read_html(str(divTables.find_all('table')[i])), axis=0) for i in range(0,lenTables)], ignore_index=True)

# Retiro as LOCALIDADES duplicadas
df_noDups = df.drop_duplicates(subset=['Localidade'])

# Crio o INDEX (iniciando por 1)
df_noDups.index = df_noDups.index + 1

# Printo o resultado no formato tabela
df_noDups
# Out:
#                    Localidade           Faixa de CEP  \
# 1       Alta Floresta D'Oeste  76954-000 a 76955-999
# 2     Alto Alegre dos Parecis  76952-000 a 76953-999
# 3                Alto Paraíso  76862-000 a 76862-999
# 4            Alvorada D'Oeste  76930-000 a 76931-999
# 5                   Ariquemes  76870-001 a 76879-999
# 7                     Buritis  76880-000 a 76886-999
# 8                      Cabixi  76994-000 a 76994-999
# 9                 Cacaulândia  76889-000 a 76889-999
# 10                     Cacoal  76960-001 a 76969-999
# 12     Campo Novo de Rondônia  76887-000 a 76887-999
# 13         Candeias do Jamari  76860-000 a 76860-999
# 14               Castanheiras  76948-000 a 76949-999
# 15                 Cerejeiras  76997-000 a 76998-999
# 16                Chupinguaia  76990-000 a 76992-999
# 17          Colorado do Oeste  76993-000 a 76993-999
# 18                 Corumbiara  76995-000 a 76996-999
# 19              Costa Marques  76937-000 a 76939-999
# 20                    Cujubim  76864-000 a 76865-999
# 21            Espigão D'Oeste  76974-000 a 76975-999
# 22  Governador Jorge Teixeira  76898-000 a 76899-999
# 23              Guajará-Mirim  76850-000 a 76856-999
# 24            Itapuã do Oeste  76861-000 a 76861-999
# 25                       Jaru  76890-000 a 76897-999
# 26                  Ji-Paraná  76900-001 a 76915-999
# 28         Machadinho D'Oeste  76868-000 a 76869-999
# 29         Ministro Andreazza  76919-000 a 76919-999
# 30           Mirante da Serra  76926-000 a 76927-999
# 31                Monte Negro  76888-000 a 76888-999
# 32   Nova Brasilândia D'Oeste  76958-000 a 76959-999
# 33                Nova Mamoré  76857-000 a 76859-999
# 34                 Nova União  76924-000 a 76925-999
# 35    Novo Horizonte do Oeste  76956-000 a 76957-999
# 36        Ouro Preto do Oeste  76920-000 a 76922-999
# 37                    Parecis  76979-000 a 76979-999
# 38              Pimenta Bueno  76970-000 a 76973-999
# 39       Pimenteiras do Oeste  76999-000 a 76999-999
# 40                Porto Velho  76800-001 a 76849-999
# 42          Presidente Médici  76916-000 a 76918-999
# 43      Primavera de Rondônia  76976-000 a 76976-999
# 44                 Rio Crespo  76863-000 a 76863-999
# 45             Rolim de Moura  76940-000 a 76947-999
# 46        Santa Luzia D'Oeste  76950-000 a 76951-999
# 47         São Felipe D'Oeste  76977-000 a 76978-999
# 48   São Francisco do Guaporé  76935-000 a 76936-999
# 49      São Miguel do Guaporé  76932-000 a 76933-999
# 50               Seringueiras  76934-000 a 76934-999
# 51              Teixeirópolis  76928-000 a 76928-999
# 52                  Theobroma  76866-000 a 76866-999
# 53                      Urupá  76929-000 a 76929-999
# 54              Vale do Anari  76867-000 a 76867-999
# 55            Vale do Paraíso  76923-000 a 76923-999
# 56                    Vilhena  76980-001 a 76989-999
#
#                           Situação       Tipo de Faixa
# 1   Não codificada por logradouros  Total do município
# 2   Não codificada por logradouros  Total do município
# 3   Não codificada por logradouros  Total do município
# 4   Não codificada por logradouros  Total do município
# 5       Codificado por logradouros  Total do município
# 7   Não codificada por logradouros  Total do município
# 8   Não codificada por logradouros  Total do município
# 9   Não codificada por logradouros  Total do município
# 10      Codificado por logradouros  Total do município
# 12  Não codificada por logradouros  Total do município
# 13  Não codificada por logradouros  Total do município
# 14  Não codificada por logradouros  Total do município
# 15  Não codificada por logradouros  Total do município
# 16  Não codificada por logradouros  Total do município
# 17  Não codificada por logradouros  Total do município
# 18  Não codificada por logradouros  Total do município
# 19  Não codificada por logradouros  Total do município
# 20  Não codificada por logradouros  Total do município
# 21  Não codificada por logradouros  Total do município
# 22  Não codificada por logradouros  Total do município
# 23  Não codificada por logradouros  Total do município
# 24  Não codificada por logradouros  Total do município
# 25  Não codificada por logradouros  Total do município
# 26      Codificado por logradouros  Total do município
# 28  Não codificada por logradouros  Total do município
# 29  Não codificada por logradouros  Total do município
# 30  Não codificada por logradouros  Total do município
# 31  Não codificada por logradouros  Total do município
# 32  Não codificada por logradouros  Total do município
# 33  Não codificada por logradouros  Total do município
# 34  Não codificada por logradouros  Total do município
# 35  Não codificada por logradouros  Total do município
# 36  Não codificada por logradouros  Total do município
# 37  Não codificada por logradouros  Total do município
# 38  Não codificada por logradouros  Total do município
# 39  Não codificada por logradouros  Total do município
# 40      Codificado por logradouros  Total do município
# 42  Não codificada por logradouros  Total do município
# 43  Não codificada por logradouros  Total do município
# 44  Não codificada por logradouros  Total do município
# 45  Não codificada por logradouros  Total do município
# 46  Não codificada por logradouros  Total do município
# 47  Não codificada por logradouros  Total do município
# 48  Não codificada por logradouros  Total do município
# 49  Não codificada por logradouros  Total do município
# 50  Não codificada por logradouros  Total do município
# 51  Não codificada por logradouros  Total do município
# 52  Não codificada por logradouros  Total do município
# 53  Não codificada por logradouros  Total do município
# 54  Não codificada por logradouros  Total do município
# 55  Não codificada por logradouros  Total do município
# 56      Codificado por logradouros  Total do município

# %%
# Resultado no formato JSONL
result = df_noDups.to_json(orient="records", lines=True)

# Printo o resultado no formato JSONL
result
# Out:
# '{"Localidade":"Alta Floresta D\'Oeste","Faixa de CEP":"76954-000 a 76955-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Alto Alegre dos Parecis","Faixa de CEP":"76952-000 a 76953-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Alto Para\\u00edso","Faixa de CEP":"76862-000 a 76862-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Alvorada D\'Oeste","Faixa de CEP":"76930-000 a 76931-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Ariquemes","Faixa de CEP":"76870-001 a 76879-999","Situa\\u00e7\\u00e3o":"Codificado por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Buritis","Faixa de CEP":"76880-000 a 76886-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Cabixi","Faixa de CEP":"76994-000 a 76994-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Cacaul\\u00e2ndia","Faixa de CEP":"76889-000 a 76889-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Cacoal","Faixa de CEP":"76960-001 a 76969-999","Situa\\u00e7\\u00e3o":"Codificado por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Campo Novo de Rond\\u00f4nia","Faixa de CEP":"76887-000 a 76887-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Candeias do Jamari","Faixa de CEP":"76860-000 a 76860-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Castanheiras","Faixa de CEP":"76948-000 a 76949-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Cerejeiras","Faixa de CEP":"76997-000 a 76998-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Chupinguaia","Faixa de CEP":"76990-000 a 76992-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Colorado do Oeste","Faixa de CEP":"76993-000 a 76993-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Corumbiara","Faixa de CEP":"76995-000 a 76996-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Costa Marques","Faixa de CEP":"76937-000 a 76939-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Cujubim","Faixa de CEP":"76864-000 a 76865-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Espig\\u00e3o D\'Oeste","Faixa de CEP":"76974-000 a 76975-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Governador Jorge Teixeira","Faixa de CEP":"76898-000 a 76899-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Guajar\\u00e1-Mirim","Faixa de CEP":"76850-000 a 76856-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Itapu\\u00e3 do Oeste","Faixa de CEP":"76861-000 a 76861-999","Situa\\u00e7\\u00e3o":"N\\u00e3o codificada por logradouros","Tipo de Faixa":"Total do munic\\u00edpio"}\n{"Localidade":"Jaru","Faixa de CEP":"76890-000 a 76897-999","Situa\\u00e7\\u00e3o":"N\\u00e3o c ...

# %%
# Salvando o resultado JSONL na pasta Documents
df_noDups.to_json(r'C:\Users\admin\Documents\Export_DataFrame_'+UF_escolha+'.json', orient='records', lines=True)
